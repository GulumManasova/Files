# %% [markdown]
# ------------
# <h1 align='center'>  <font size = '8' color='red'> Masters Programme in Buisiness Analytics  <font> </h1>
#
# <h1 align='center'>  <font size = '6' color='green'> Advanced Data Analytics and Visualization Mid Term Part II  <font> </h1>
#
# ![logo_aiu.png](attachment:logo_aiu.png)
#
#
#
# <center align="left"> Ala-too International University </center>
#
#   <center align="left">    <center align="left"><center align="left"> <font color='dark blue'><font style= 'bold' size='3' color='dark'>  Instructor: Dr Remudin Reshid MEKURIA <font> </center>

# %% [markdown]
# **Exercise 1:** Student Grades with Highest Score
# Create a data frame to maintain five students’ names and their grades in four subjects. Then, add a
# new column named Highest Score to store each student's highest grade. Display the final data
# frame.

# %%
#your codes here!

# %% [markdown]
# **Exercise 2:**  Class Performance Summary
# Create a data frame with four students' names and their scores in three subjects. Then, add two
# new columns:
# 1. Mean Score – The average score per student.
# 2. Pass/Fail – Mark students as "Pass" if their average score is ≥ 50, otherwise "Fail".
# Display the final data frame.

# %%
#your codes here!

# %% [markdown]
# **Exercise 3:**  Course-Wise Averages
# Create a data frame with six students' names and their grades in three courses. Then, add a new
# row named Course Average, which contains the average score for each course. Display the final
# data frame.

# %%
#your codes here!

# %% [markdown]
# **Exercise 4:** Ranking Students
# Create a data frame with five students' names and their scores in four subjects. Then:
# 1. Calculate the total marks for each student and store them in a new column.
# 2. Sort the data frame in descending order based on total marks.
# 3. Add a new column named Rank to assign ranks to students (Rank 1 for the highest total
# score).
# Display the final data frame.

# %%
#your codes here!

# %% [markdown]
# **Exercise 5:** Write a Python script to create a data frame for the following table:

# %% [markdown]
# ![table.png](attachment:table.png)

# %% [markdown]
# For the created data frame in the previous question, do the following:
# 1. Create a bar plot of the sales volume.
# 2. Create a pie chart of item sales.
# 3. Create a box plot of item sales.
# 4. Create an area plot of item sales.
# 5. Create a stacked bar plot of item sales.
